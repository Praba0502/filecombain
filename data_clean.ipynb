# %%
import pandas as pd

# %%
df1=pd.read_excel("file_1.xlsx")

# %%
df1.head()
# Out:
#                                           Unnamed: 0  \
# 0                                        TAX INVOICE
# 1  Invoice From : Swiggy Limited (formerly known ...
# 2                                           Sr.\nno.
# 3                                                  1
# 4                                                  2
#
#                     Unnamed: 1  None_1            None_2    None_3  \
# 0                          NaN     NaN               NaN       NaN
# 1                          NaN     NaN               NaN       NaN
# 2                  Description     HSN  Unit of\nmeasure  Quantity
# 3                  Service Fee  996211               OTH         1
# 4  Long Distance Pack\ncharges  996211               OTH         1
#
#        None_4       None_5    None_6             None_7      None_8  ...  \
# 0         NaN          NaN       NaN                NaN         NaN  ...
# 1         NaN          NaN       NaN                NaN         NaN  ...
# ...

# %%
df1
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5                                                 NaN
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %%
df1=df1.fillna('')
df1
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
#
#                               Unnamed: 1  None_1            None_2  \
# 0
# 1
# 2                            Description     HSN  Unit of\nmeasure
# 3                            Service Fee  996211               OTH
# 4            Long Distance Pack\ncharges  996211               OTH
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# ...

# %%
df1 = df1.dropna(axis=1, how='all')

# %%
df1
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
#
#                               Unnamed: 1  None_1            None_2  \
# 0
# 1
# 2                            Description     HSN  Unit of\nmeasure
# 3                            Service Fee  996211               OTH
# 4            Long Distance Pack\ncharges  996211               OTH
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# ...

# %%
header_row_index = 2

# %%
new_header = df1.iloc[header_row_index]       # get the header row
df1 = df1.iloc[header_row_index + 1:]          # keep the data below it
df1.columns = new_header                      # set new header
df1 = df1.reset_index(drop=True)               # reset index

# Step 3 (Optional): Clean newline characters from headers
df1.columns = df1.columns.str.replace('\n', ' ', regex=True)

# Step 4: Preview result
print(df1.head())
# Out:
# 2                                     Sr. no.                  Description  \
# 0                                           1                  Service Fee
# 1                                           2  Long Distance Pack\ncharges
# 2
# 3                                    SubTotal
# 4  Other Charges - Reimbursement\nof Discount
#
# 2     HSN Unit of measure   Quantity Unit Price Base Amount Discount  \
# 0  996211             OTH          1   9,386.58    9,386.58        0
# 1  996211             OTH          1        140         140        0
# 2
# 3                                                  9,526.58
# 4                          12,751.39
#
# 2 Assessable value CGST Rate  ... SGST Rate SGST Amount IGST Rate IGST Amount  \
# 0         9,386.58         9  ...         9     844.792         0           0
# 1              140         9  ...         9        12.6         0           0
# 2                             ...
# ...

# %%
df1
# Out:
# 2                                             Sr. no.  \
# 0                                                   1
# 1                                                   2
# 2
# 3                                            SubTotal
# 4          Other Charges - Reimbursement\nof Discount
# 5                                         Grand Total
# 6                                     Amount in Words
# 7   Digitally Signed by\nAuthorised Signature Swig...
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15
#
# 2                            Description     HSN Unit of measure  \
# 0                            Service Fee  996211             OTH
# 1            Long Distance Pack\ncharges  996211             OTH
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9     Bundl Technologies Private Limited
# 10       CURRENT A/c. No. 50200003950522
# 11  HDFC BANK LTD, KORAMANGALA 4TH BLOCK
# 12                         Wire Transfer
# 13                           HDFC0002777
# 14                             560240076
# ...

# %%
df1
# Out:
# 2                                             Sr. no.  \
# 0                                                   1
# 1                                                   2
# 2
# 3                                            SubTotal
# 4          Other Charges - Reimbursement\nof Discount
# 5                                         Grand Total
# 6                                     Amount in Words
# 7   Digitally Signed by\nAuthorised Signature Swig...
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15
#
# 2                            Description     HSN Unit of measure  \
# 0                            Service Fee  996211             OTH
# 1            Long Distance Pack\ncharges  996211             OTH
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9     Bundl Technologies Private Limited
# 10       CURRENT A/c. No. 50200003950522
# 11  HDFC BANK LTD, KORAMANGALA 4TH BLOCK
# 12                         Wire Transfer
# 13                           HDFC0002777
# 14                             560240076
# ...

# %%
for x in df1.index:
    if df1.loc[x, "Unit of measure"] == '':
        df1.drop(x, inplace=True)

df1
# Out:
# 2 Sr. no.                  Description     HSN Unit of measure Quantity  \
# 0       1                  Service Fee  996211             OTH        1
# 1       2  Long Distance Pack\ncharges  996211             OTH        1
#
# 2 Unit Price Base Amount Discount Assessable value CGST Rate  ... SGST Rate  \
# 0   9,386.58    9,386.58        0         9,386.58         9  ...         9
# 1        140         140        0              140         9  ...         9
#
# 2 SGST Amount IGST Rate IGST Amount Comp CESS Rate Comp CESS Amount  \
# 0     844.792         0           0              0                0
# 1        12.6         0           0              0                0
#
# 2 State CESS Rate State CESS Amount Total Amount (Rs.)
# 0               0                 0         11,076.164
# 1               0                 0              165.2
#
# [2 rows x 21 columns]

# %%
df1 = df1.drop(df1.columns[0], axis=1)

# %%
df1
# Out:
# 2                  Description     HSN Unit of measure Quantity Unit Price  \
# 0                  Service Fee  996211             OTH        1   9,386.58
# 1  Long Distance Pack\ncharges  996211             OTH        1        140
#
# 2 Base Amount Discount Assessable value CGST Rate CGST Amount SGST Rate  \
# 0    9,386.58        0         9,386.58         9     844.792         9
# 1         140        0              140         9        12.6         9
#
# 2 SGST Amount IGST Rate IGST Amount Comp CESS Rate Comp CESS Amount  \
# 0     844.792         0           0              0                0
# 1        12.6         0           0              0                0
#
# 2 State CESS Rate State CESS Amount Total Amount (Rs.)
# 0               0                 0         11,076.164
# 1               0                 0              165.2

# %%
df2=pd.read_excel("file_2.xlsx")

# %%
df2.head()
# Out:
#                                           Unnamed: 0   Unnamed: 1  None_1  \
# 0                                        TAX INVOICE          NaN     NaN
# 1  Invoice From : Swiggy Limited (formerly known ...          NaN     NaN
# 2                                           Sr.\nno.  Description     HSN
# 3                                                  1  Service Fee  996211
# 4                                                NaN          NaN     NaN
#
#              None_2    None_3      None_4       None_5    None_6  \
# 0               NaN       NaN         NaN          NaN       NaN
# 1               NaN       NaN         NaN          NaN       NaN
# 2  Unit of\nmeasure  Quantity  Unit Price  Base Amount  Discount
# 3               OTH         1       36.99        36.99         0
# 4               NaN       NaN         NaN          NaN       NaN
#
#               None_7      None_8  ...     None_10      None_11     None_12  \
# ...

# %%
df2=df2.fillna('')
df2
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4
# 5                                            SubTotal
# 6          Other Charges - Reimbursement\nof Discount
# 7                                         Grand Total
# 8                                     Amount in Words
# 9   Digitally Signed by\nAuthorised Signature Swig...
# 10
# 11
# 12
# 13
# 14
# 15
# 16
# 17
#
#                               Unnamed: 1  None_1            None_2  \
# 0
# 1
# 2                            Description     HSN  Unit of\nmeasure
# 3                            Service Fee  996211               OTH
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 11    Bundl Technologies Private Limited
# 12       CURRENT A/c. No. 50200003950522
# 13  HDFC BANK LTD, KORAMANGALA 4TH BLOCK
# ...

# %%
df2.drop_duplicates()
df2
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4
# 5                                            SubTotal
# 6          Other Charges - Reimbursement\nof Discount
# 7                                         Grand Total
# 8                                     Amount in Words
# 9   Digitally Signed by\nAuthorised Signature Swig...
# 10
# 11
# 12
# 13
# 14
# 15
# 16
# 17
#
#                               Unnamed: 1  None_1            None_2  \
# 0
# 1
# 2                            Description     HSN  Unit of\nmeasure
# 3                            Service Fee  996211               OTH
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 11    Bundl Technologies Private Limited
# 12       CURRENT A/c. No. 50200003950522
# 13  HDFC BANK LTD, KORAMANGALA 4TH BLOCK
# ...

# %%
header_row_index = 2
new_header = df2.iloc[header_row_index]       # get the header row
df2 = df2.iloc[header_row_index + 1:]          # keep the data below it
df2.columns = new_header                      # set new header
df2 = df2.reset_index(drop=True)               # reset index

# %%
df2
# Out:
# 2                                            Sr.\nno.  \
# 0                                                   1
# 1
# 2                                            SubTotal
# 3          Other Charges - Reimbursement\nof Discount
# 4                                         Grand Total
# 5                                     Amount in Words
# 6   Digitally Signed by\nAuthorised Signature Swig...
# 7
# 8
# 9
# 10
# 11
# 12
# 13
# 14
#
# 2                            Description     HSN Unit of\nmeasure  \
# 0                            Service Fee  996211              OTH
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8     Bundl Technologies Private Limited
# 9        CURRENT A/c. No. 50200003950522
# 10  HDFC BANK LTD, KORAMANGALA 4TH BLOCK
# 11                         Wire Transfer
# 12                           HDFC0002777
# 13                             560240076
# 14                              HDFCINBB
#
# 2                                            Quantity Unit Price Base Amount  \
# ...

# %%
df2.columns = df2.columns.str.replace('\n', ' ', regex=True)

# %%
df2
# Out:
# 2                                             Sr. no.  \
# 0                                                   1
# 1
# 2                                            SubTotal
# 3          Other Charges - Reimbursement\nof Discount
# 4                                         Grand Total
# 5                                     Amount in Words
# 6   Digitally Signed by\nAuthorised Signature Swig...
# 7
# 8
# 9
# 10
# 11
# 12
# 13
# 14
#
# 2                            Description     HSN Unit of measure  \
# 0                            Service Fee  996211             OTH
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8     Bundl Technologies Private Limited
# 9        CURRENT A/c. No. 50200003950522
# 10  HDFC BANK LTD, KORAMANGALA 4TH BLOCK
# 11                         Wire Transfer
# 12                           HDFC0002777
# 13                             560240076
# 14                              HDFCINBB
#
# 2                                            Quantity Unit Price Base Amount  \
# ...

# %%
for x in df2.index:
    if df2.loc[x, "Unit of measure"] == '':
        df2.drop(x, inplace=True)

df2
# Out:
# 2 Sr. no.  Description     HSN Unit of measure Quantity Unit Price  \
# 0       1  Service Fee  996211             OTH        1      36.99
#
# 2 Base Amount Discount Assessable value CGST Rate  ... SGST Rate SGST Amount  \
# 0       36.99        0            36.99         9  ...         9       3.329
#
# 2 IGST Rate IGST Amount Comp CESS Rate Comp CESS Amount State CESS Rate  \
# 0         0           0              0                0               0
#
# 2 State CESS Amount Total Amount (Rs.)
# 0                 0             43.648
#
# [1 rows x 21 columns]

# %%
df3=pd.read_excel("file_3.xlsx")

# %%
df3
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5                                                 NaN
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %%
df3=df3.fillna('')
df3
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
#
#                               Unnamed: 1  None_1            None_2  \
# 0
# 1
# 2                            Description     HSN  Unit of\nmeasure
# 3                            Service Fee  996211               OTH
# 4            Long Distance Pack\ncharges  996211               OTH
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# ...

# %%
df3.drop_duplicates()
df3
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
#
#                               Unnamed: 1  None_1            None_2  \
# 0
# 1
# 2                            Description     HSN  Unit of\nmeasure
# 3                            Service Fee  996211               OTH
# 4            Long Distance Pack\ncharges  996211               OTH
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# ...

# %%
header_row_index = 2

# %%
new_header = df3.iloc[header_row_index]       # get the header row
df3 = df3.iloc[header_row_index + 1:]          # keep the data below it
df3.columns = new_header                      # set new header
df3 = df3.reset_index(drop=True)               # reset index

# %%
df3
# Out:
# 2                                            Sr.\nno.  \
# 0                                                   1
# 1                                                   2
# 2
# 3                                            SubTotal
# 4          Other Charges - Reimbursement\nof Discount
# 5                                         Grand Total
# 6                                     Amount in Words
# 7   Digitally Signed by\nAuthorised Signature Swig...
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15
#
# 2                            Description     HSN Unit of\nmeasure  \
# 0                            Service Fee  996211              OTH
# 1            Long Distance Pack\ncharges  996211              OTH
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9     Bundl Technologies Private Limited
# 10       CURRENT A/c. No. 50200003950522
# 11  HDFC BANK LTD, KORAMANGALA 4TH BLOCK
# 12                         Wire Transfer
# 13                           HDFC0002777
# 14                             560240076
# ...

# %%
df3.columns = df3.columns.str.replace('\n', ' ', regex=True)
df3
# Out:
# 2                                             Sr. no.  \
# 0                                                   1
# 1                                                   2
# 2
# 3                                            SubTotal
# 4          Other Charges - Reimbursement\nof Discount
# 5                                         Grand Total
# 6                                     Amount in Words
# 7   Digitally Signed by\nAuthorised Signature Swig...
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15
#
# 2                            Description     HSN Unit of measure  \
# 0                            Service Fee  996211             OTH
# 1            Long Distance Pack\ncharges  996211             OTH
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9     Bundl Technologies Private Limited
# 10       CURRENT A/c. No. 50200003950522
# 11  HDFC BANK LTD, KORAMANGALA 4TH BLOCK
# 12                         Wire Transfer
# 13                           HDFC0002777
# 14                             560240076
# ...

# %%
for x in df3.index:
    if df3.loc[x, "Unit of measure"] == '':
        df3.drop(x, inplace=True)

df3
# Out:
# 2 Sr. no.                  Description     HSN Unit of measure Quantity  \
# 0       1                  Service Fee  996211             OTH        1
# 1       2  Long Distance Pack\ncharges  996211             OTH        1
#
# 2 Unit Price Base Amount Discount Assessable value CGST Rate  ... SGST Rate  \
# 0  13,579.92   13,579.92        0        13,579.92         9  ...         9
# 1        805         805        0              805         9  ...         9
#
# 2 SGST Amount IGST Rate IGST Amount Comp CESS Rate Comp CESS Amount  \
# 0   1,222.193         0           0              0                0
# 1       72.45         0           0              0                0
#
# 2 State CESS Rate State CESS Amount Total Amount (Rs.)
# 0               0                 0         16,024.306
# 1               0                 0              949.9
#
# [2 rows x 21 columns]

# %%
df4=pd.read_excel("file_4.xlsx")
df4
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5                                                 NaN
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %%
df4=df4.fillna('')
df4
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
#
#                               Unnamed: 1  None_1            None_2  \
# 0
# 1
# 2                            Description     HSN  Unit of\nmeasure
# 3                            Service Fee  996211               OTH
# 4            Long Distance Pack\ncharges  996211               OTH
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# ...

# %%
df4.drop_duplicates()
df4
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
#
#                               Unnamed: 1  None_1            None_2  \
# 0
# 1
# 2                            Description     HSN  Unit of\nmeasure
# 3                            Service Fee  996211               OTH
# 4            Long Distance Pack\ncharges  996211               OTH
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# ...

# %%
header_row_index = 2

# %%
new_header = df4.iloc[header_row_index]       # get the header row
df4 = df4.iloc[header_row_index + 1:]          # keep the data below it
df4.columns = new_header                      # set new header
df4 = df4.reset_index(drop=True)               # reset index

# %%
df4
# Out:
# 2                                            Sr.\nno.  \
# 0                                                   1
# 1                                                   2
# 2
# 3                                            SubTotal
# 4          Other Charges - Reimbursement\nof Discount
# 5                                         Grand Total
# 6                                     Amount in Words
# 7   Digitally Signed by\nAuthorised Signature Swig...
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15
#
# 2                            Description     HSN Unit of\nmeasure  \
# 0                            Service Fee  996211              OTH
# 1            Long Distance Pack\ncharges  996211              OTH
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9     Bundl Technologies Private Limited
# 10       CURRENT A/c. No. 50200003950522
# 11  HDFC BANK LTD, KORAMANGALA 4TH BLOCK
# 12                         Wire Transfer
# 13                           HDFC0002777
# 14                             560240076
# ...

# %%
df4.columns = df4.columns.str.replace('\n', ' ', regex=True)

# %%
for x in df4.index:
    if df4.loc[x, "Unit of measure"] == '':
        df4.drop(x, inplace=True)

df4
# Out:
# 2 Sr. no.                  Description     HSN Unit of measure Quantity  \
# 0       1                  Service Fee  996211             OTH        1
# 1       2  Long Distance Pack\ncharges  996211             OTH        1
#
# 2 Unit Price Base Amount Discount Assessable value CGST Rate  ... SGST Rate  \
# 0     626.25      626.25        0           626.25         9  ...         9
# 1        120         120        0              120         9  ...         9
#
# 2 SGST Amount IGST Rate IGST Amount Comp CESS Rate Comp CESS Amount  \
# 0      56.362         0           0              0                0
# 1        10.8         0           0              0                0
#
# 2 State CESS Rate State CESS Amount Total Amount (Rs.)
# 0               0                 0            738.975
# 1               0                 0              141.6
#
# [2 rows x 21 columns]

# %%
df5=pd.read_excel("file_5.xlsx")
df5
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5                                                 NaN
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %%
df5=df5.fillna('')
df5
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
#
#                               Unnamed: 1  None_1            None_2  \
# 0
# 1
# 2                            Description     HSN  Unit of\nmeasure
# 3                            Service Fee  996211               OTH
# 4            Long Distance Pack\ncharges  996211               OTH
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# ...

# %%
df5.drop_duplicates()
df5
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
#
#                               Unnamed: 1  None_1            None_2  \
# 0
# 1
# 2                            Description     HSN  Unit of\nmeasure
# 3                            Service Fee  996211               OTH
# 4            Long Distance Pack\ncharges  996211               OTH
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# ...

# %%
header_row_index = 2

# %%
new_header = df5.iloc[header_row_index]       # get the header row
df5 = df5.iloc[header_row_index + 1:]          # keep the data below it
df5.columns = new_header                      # set new header
df5 = df5.reset_index(drop=True)

# %%
df5
# Out:
# 2                                            Sr.\nno.  \
# 0                                                   1
# 1                                                   2
# 2
# 3                                            SubTotal
# 4          Other Charges - Reimbursement\nof Discount
# 5                                         Grand Total
# 6                                     Amount in Words
# 7   Digitally Signed by\nAuthorised Signature Swig...
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15
#
# 2                            Description     HSN Unit of\nmeasure  \
# 0                            Service Fee  996211              OTH
# 1            Long Distance Pack\ncharges  996211              OTH
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9     Bundl Technologies Private Limited
# 10       CURRENT A/c. No. 50200003950522
# 11  HDFC BANK LTD, KORAMANGALA 4TH BLOCK
# 12                         Wire Transfer
# 13                           HDFC0002777
# 14                             560240076
# ...

# %%
df5.columns = df5.columns.str.replace('\n', ' ', regex=True)

# %%
df5
# Out:
# 2                                             Sr. no.  \
# 0                                                   1
# 1                                                   2
# 2
# 3                                            SubTotal
# 4          Other Charges - Reimbursement\nof Discount
# 5                                         Grand Total
# 6                                     Amount in Words
# 7   Digitally Signed by\nAuthorised Signature Swig...
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15
#
# 2                            Description     HSN Unit of measure  \
# 0                            Service Fee  996211             OTH
# 1            Long Distance Pack\ncharges  996211             OTH
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9     Bundl Technologies Private Limited
# 10       CURRENT A/c. No. 50200003950522
# 11  HDFC BANK LTD, KORAMANGALA 4TH BLOCK
# 12                         Wire Transfer
# 13                           HDFC0002777
# 14                             560240076
# ...

# %%
for x in df5.index:
    if df5.loc[x, "Unit of measure"] == '':
        df5.drop(x, inplace=True)

df5
# Out:
# 2 Sr. no.                  Description     HSN Unit of measure Quantity  \
# 0       1                  Service Fee  996211             OTH        1
# 1       2  Long Distance Pack\ncharges  996211             OTH        1
#
# 2 Unit Price Base Amount Discount Assessable value CGST Rate  ... SGST Rate  \
# 0   9,555.89    9,555.89        0         9,555.89         9  ...         9
# 1        455         455        0              455         9  ...         9
#
# 2 SGST Amount IGST Rate IGST Amount Comp CESS Rate Comp CESS Amount  \
# 0      860.03         0           0              0                0
# 1       40.95         0           0              0                0
#
# 2 State CESS Rate State CESS Amount Total Amount (Rs.)
# 0               0                 0          11,275.95
# 1               0                 0              536.9
#
# [2 rows x 21 columns]

# %%
df6=pd.read_excel("file_6.xlsx")
df6
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5                                                 NaN
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %%
df6=df6.fillna('')
df6
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
#
#                               Unnamed: 1  None_1            None_2  \
# 0
# 1
# 2                            Description     HSN  Unit of\nmeasure
# 3                            Service Fee  996211               OTH
# 4            Long Distance Pack\ncharges  996211               OTH
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# ...

# %%
df6.drop_duplicates()
df6
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
#
#                               Unnamed: 1  None_1            None_2  \
# 0
# 1
# 2                            Description     HSN  Unit of\nmeasure
# 3                            Service Fee  996211               OTH
# 4            Long Distance Pack\ncharges  996211               OTH
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# ...

# %%
header_row_index = 2

# %%
new_header = df6.iloc[header_row_index]       # get the header row
df6 = df6.iloc[header_row_index + 1:]          # keep the data below it
df6.columns = new_header                      # set new header
df6 = df6.reset_index(drop=True)

# %%
df6
# Out:
# 2                                            Sr.\nno.  \
# 0                                                   1
# 1                                                   2
# 2
# 3                                            SubTotal
# 4          Other Charges - Reimbursement\nof Discount
# 5                                         Grand Total
# 6                                     Amount in Words
# 7   Digitally Signed by\nAuthorised Signature Swig...
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15
#
# 2                            Description     HSN Unit of\nmeasure  \
# 0                            Service Fee  996211              OTH
# 1            Long Distance Pack\ncharges  996211              OTH
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9     Bundl Technologies Private Limited
# 10       CURRENT A/c. No. 50200003950522
# 11  HDFC BANK LTD, KORAMANGALA 4TH BLOCK
# 12                         Wire Transfer
# 13                           HDFC0002777
# 14                             560240076
# ...

# %%
df6.columns = df6.columns.str.replace('\n', ' ', regex=True)
df6
# Out:
# 2                                             Sr. no.  \
# 0                                                   1
# 1                                                   2
# 2
# 3                                            SubTotal
# 4          Other Charges - Reimbursement\nof Discount
# 5                                         Grand Total
# 6                                     Amount in Words
# 7   Digitally Signed by\nAuthorised Signature Swig...
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15
#
# 2                            Description     HSN Unit of measure  \
# 0                            Service Fee  996211             OTH
# 1            Long Distance Pack\ncharges  996211             OTH
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9     Bundl Technologies Private Limited
# 10       CURRENT A/c. No. 50200003950522
# 11  HDFC BANK LTD, KORAMANGALA 4TH BLOCK
# 12                         Wire Transfer
# 13                           HDFC0002777
# 14                             560240076
# ...

# %%
for x in df6.index:
    if df6.loc[x, "Unit of measure"] == '':
        df6.drop(x, inplace=True)

df6
# Out:
# 2 Sr. no.                  Description     HSN Unit of measure Quantity  \
# 0       1                  Service Fee  996211             OTH        1
# 1       2  Long Distance Pack\ncharges  996211             OTH        1
#
# 2 Unit Price Base Amount Discount Assessable value CGST Rate  ... SGST Rate  \
# 0   4,061.76    4,061.76        0         4,061.76         9  ...         9
# 1        270         270        0              270         9  ...         9
#
# 2 SGST Amount IGST Rate IGST Amount Comp CESS Rate Comp CESS Amount  \
# 0     365.558         0           0              0                0
# 1        24.3         0           0              0                0
#
# 2 State CESS Rate State CESS Amount Total Amount (Rs.)
# 0               0                 0          4,792.877
# 1               0                 0              318.6
#
# [2 rows x 21 columns]

# %%
df7=pd.read_excel("file_7.xlsx")
df7
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5                                                 NaN
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %%
df7=df7.fillna('')
df7.drop_duplicates()
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
#
#                               Unnamed: 1  None_1            None_2  \
# 0
# 1
# 2                            Description     HSN  Unit of\nmeasure
# 3                            Service Fee  996211               OTH
# 4            Long Distance Pack\ncharges  996211               OTH
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# ...

# %%
header_row_index = 2
new_header = df7.iloc[header_row_index]       # get the header row
df7 = df7.iloc[header_row_index + 1:]          # keep the data below it
df7.columns = new_header                      # set new header
df7 = df7.reset_index(drop=True)               # reset index

# %%
df7
# Out:
# 2                                            Sr.\nno.  \
# 0                                                   1
# 1                                                   2
# 2
# 3                                            SubTotal
# 4          Other Charges - Reimbursement\nof Discount
# 5                                         Grand Total
# 6                                     Amount in Words
# 7   Digitally Signed by\nAuthorised Signature Swig...
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15
#
# 2                            Description     HSN Unit of\nmeasure  \
# 0                            Service Fee  996211              OTH
# 1            Long Distance Pack\ncharges  996211              OTH
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9     Bundl Technologies Private Limited
# 10       CURRENT A/c. No. 50200003950522
# 11  HDFC BANK LTD, KORAMANGALA 4TH BLOCK
# 12                         Wire Transfer
# 13                           HDFC0002777
# 14                             560240076
# ...

# %%
df7.columns = df7.columns.str.replace('\n', ' ', regex=True)

# %%
df7
# Out:
# 2                                             Sr. no.  \
# 0                                                   1
# 1                                                   2
# 2
# 3                                            SubTotal
# 4          Other Charges - Reimbursement\nof Discount
# 5                                         Grand Total
# 6                                     Amount in Words
# 7   Digitally Signed by\nAuthorised Signature Swig...
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15
#
# 2                            Description     HSN Unit of measure  \
# 0                            Service Fee  996211             OTH
# 1            Long Distance Pack\ncharges  996211             OTH
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9     Bundl Technologies Private Limited
# 10       CURRENT A/c. No. 50200003950522
# 11  HDFC BANK LTD, KORAMANGALA 4TH BLOCK
# 12                         Wire Transfer
# 13                           HDFC0002777
# 14                             560240076
# ...

# %%
for x in df7.index:
    if df7.loc[x, "Unit of measure"] == '':
        df7.drop(x, inplace=True)

df7
# Out:
# 2 Sr. no.                  Description     HSN Unit of measure Quantity  \
# 0       1                  Service Fee  996211             OTH        1
# 1       2  Long Distance Pack\ncharges  996211             OTH        1
#
# 2 Unit Price Base Amount Discount Assessable value CGST Rate  ... SGST Rate  \
# 0   2,139.16    2,139.16        0         2,139.16         9  ...         9
# 1        330         330        0              330         9  ...         9
#
# 2 SGST Amount IGST Rate IGST Amount Comp CESS Rate Comp CESS Amount  \
# 0     192.524         0           0              0                0
# 1        29.7         0           0              0                0
#
# 2 State CESS Rate State CESS Amount Total Amount (Rs.)
# 0               0                 0          2,524.209
# 1               0                 0              389.4
#
# [2 rows x 21 columns]

# %%
df8=pd.read_excel("file_8.xlsx")
df8.head()
# Out:
#                                           Unnamed: 0  \
# 0                                        TAX INVOICE
# 1  Invoice From : Swiggy Limited (formerly known ...
# 2                                           Sr.\nno.
# 3                                                  1
# 4                                                  2
#
#                     Unnamed: 1  None_1            None_2    None_3  \
# 0                          NaN     NaN               NaN       NaN
# 1                          NaN     NaN               NaN       NaN
# 2                  Description     HSN  Unit of\nmeasure  Quantity
# 3                  Service Fee  996211               OTH         1
# 4  Long Distance Pack\ncharges  996211               OTH         1
#
#        None_4       None_5    None_6             None_7      None_8  ...  \
# 0         NaN          NaN       NaN                NaN         NaN  ...
# 1         NaN          NaN       NaN                NaN         NaN  ...
# ...

# %%
df8=df8.fillna('')
df8
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
#
#                               Unnamed: 1  None_1            None_2  \
# 0
# 1
# 2                            Description     HSN  Unit of\nmeasure
# 3                            Service Fee  996211               OTH
# 4            Long Distance Pack\ncharges  996211               OTH
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# ...

# %%
df8.drop_duplicates()
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
#
#                               Unnamed: 1  None_1            None_2  \
# 0
# 1
# 2                            Description     HSN  Unit of\nmeasure
# 3                            Service Fee  996211               OTH
# 4            Long Distance Pack\ncharges  996211               OTH
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# ...

# %%
header_row_index = 2
new_header = df8.iloc[header_row_index]       # get the header row
df8 = df8.iloc[header_row_index + 1:]          # keep the data below it
df8.columns = new_header                      # set new header
df8 = df8.reset_index(drop=True)               # reset index

# %%
df8
# Out:
# 2                                            Sr.\nno.  \
# 0                                                   1
# 1                                                   2
# 2
# 3                                            SubTotal
# 4          Other Charges - Reimbursement\nof Discount
# 5                                         Grand Total
# 6                                     Amount in Words
# 7   Digitally Signed by\nAuthorised Signature Swig...
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15
#
# 2                            Description     HSN Unit of\nmeasure  \
# 0                            Service Fee  996211              OTH
# 1            Long Distance Pack\ncharges  996211              OTH
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9     Bundl Technologies Private Limited
# 10       CURRENT A/c. No. 50200003950522
# 11  HDFC BANK LTD, KORAMANGALA 4TH BLOCK
# 12                         Wire Transfer
# 13                           HDFC0002777
# 14                             560240076
# ...

# %%
df8.columns = df8.columns.str.replace('\n', ' ', regex=True)

# %%
for x in df8.index:
    if df8.loc[x, "Unit of measure"] == '':
        df8.drop(x, inplace=True)

df8
# Out:
# 2 Sr. no.                  Description     HSN Unit of measure Quantity  \
# 0       1                  Service Fee  996211             OTH        1
# 1       2  Long Distance Pack\ncharges  996211             OTH        1
#
# 2 Unit Price Base Amount Discount Assessable value CGST Rate  ... SGST Rate  \
# 0   2,520.61    2,520.61        0         2,520.61         9  ...         9
# 1        140         140        0              140         9  ...         9
#
# 2 SGST Amount IGST Rate IGST Amount Comp CESS Rate Comp CESS Amount  \
# 0     226.855         0           0              0                0
# 1        12.6         0           0              0                0
#
# 2 State CESS Rate State CESS Amount Total Amount (Rs.)
# 0               0                 0           2,974.32
# 1               0                 0              165.2
#
# [2 rows x 21 columns]

# %%
df9=pd.read_excel("file_9.xlsx")
df9.head()
# Out:
#                                           Unnamed: 0  \
# 0                                        TAX INVOICE
# 1  Invoice From : Swiggy Limited (formerly known ...
# 2                                           Sr.\nno.
# 3                                                  1
# 4                                                  2
#
#                     Unnamed: 1  None_1            None_2    None_3  \
# 0                          NaN     NaN               NaN       NaN
# 1                          NaN     NaN               NaN       NaN
# 2                  Description     HSN  Unit of\nmeasure  Quantity
# 3                  Service Fee  996211               OTH         1
# 4  Long Distance Pack\ncharges  996211               OTH         1
#
#        None_4       None_5    None_6             None_7      None_8  ...  \
# 0         NaN          NaN       NaN                NaN         NaN  ...
# 1         NaN          NaN       NaN                NaN         NaN  ...
# ...

# %%
df9=df9.fillna('')
df9.drop_duplicates()
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
#
#                               Unnamed: 1  None_1            None_2  \
# 0
# 1
# 2                            Description     HSN  Unit of\nmeasure
# 3                            Service Fee  996211               OTH
# 4            Long Distance Pack\ncharges  996211               OTH
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# ...

# %%
header_row_index = 2

# %%
new_header = df9.iloc[header_row_index]       # get the header row
df9 = df9.iloc[header_row_index + 1:]          # keep the data below it
df9.columns = new_header                      # set new header
df9 = df9.reset_index(drop=True)

# %%
df9
# Out:
# 2                                            Sr.\nno.  \
# 0                                                   1
# 1                                                   2
# 2
# 3                                            SubTotal
# 4          Other Charges - Reimbursement\nof Discount
# 5                                         Grand Total
# 6                                     Amount in Words
# 7   Digitally Signed by\nAuthorised Signature Swig...
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15
#
# 2                            Description     HSN Unit of\nmeasure  \
# 0                            Service Fee  996211              OTH
# 1            Long Distance Pack\ncharges  996211              OTH
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9     Bundl Technologies Private Limited
# 10       CURRENT A/c. No. 50200003950522
# 11  HDFC BANK LTD, KORAMANGALA 4TH BLOCK
# 12                         Wire Transfer
# 13                           HDFC0002777
# 14                             560240076
# ...

# %%
df9.columns = df9.columns.str.replace('\n', ' ', regex=True)

# %%
for x in df9.index:
    if df9.loc[x, "Unit of measure"] == '':
        df9.drop(x, inplace=True)

df9
# Out:
# 2 Sr. no.                  Description     HSN Unit of measure Quantity  \
# 0       1                  Service Fee  996211             OTH        1
# 1       2  Long Distance Pack\ncharges  996211             OTH        1
#
# 2 Unit Price Base Amount Discount Assessable value CGST Rate  ... SGST Rate  \
# 0   1,025.39    1,025.39        0         1,025.39         9  ...         9
# 1         40          40        0               40         9  ...         9
#
# 2 SGST Amount IGST Rate IGST Amount Comp CESS Rate Comp CESS Amount  \
# 0      92.285         0           0              0                0
# 1         3.6         0           0              0                0
#
# 2 State CESS Rate State CESS Amount Total Amount (Rs.)
# 0               0                 0           1,209.96
# 1               0                 0               47.2
#
# [2 rows x 21 columns]

# %%
df10=pd.read_excel("file_10.xlsx")
df10.head()
# Out:
#                                           Unnamed: 0  \
# 0                                        TAX INVOICE
# 1  Invoice From : Swiggy Limited (formerly known ...
# 2                                           Sr.\nno.
# 3                                                  1
# 4                                                  2
#
#                     Unnamed: 1  None_1            None_2    None_3  \
# 0                          NaN     NaN               NaN       NaN
# 1                          NaN     NaN               NaN       NaN
# 2                  Description     HSN  Unit of\nmeasure  Quantity
# 3                  Service Fee  996211               OTH         1
# 4  Long Distance Pack\ncharges  996211               OTH         1
#
#        None_4       None_5    None_6             None_7      None_8  ...  \
# 0         NaN          NaN       NaN                NaN         NaN  ...
# 1         NaN          NaN       NaN                NaN         NaN  ...
# ...

# %%
df10=df10.fillna('')
df10.drop_duplicates()
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
#
#                               Unnamed: 1  None_1            None_2  \
# 0
# 1
# 2                            Description     HSN  Unit of\nmeasure
# 3                            Service Fee  996211               OTH
# 4            Long Distance Pack\ncharges  996211               OTH
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# ...

# %%
header_row_index = 2

# %%
new_header = df10.iloc[header_row_index]       # get the header row
df10 = df10.iloc[header_row_index + 1:]          # keep the data below it
df10.columns = new_header                      # set new header
df10 = df10.reset_index(drop=True)

# %%
df10.columns = df10.columns.str.replace('\n', ' ', regex=True)

# %%
for x in df10.index:
    if df10.loc[x, "Unit of measure"] == '':
        df10.drop(x, inplace=True)

df10
# Out:
# 2 Sr. no.                  Description     HSN Unit of measure Quantity  \
# 0       1                  Service Fee  996211             OTH        1
# 1       2  Long Distance Pack\ncharges  996211             OTH        1
#
# 2 Unit Price Base Amount Discount Assessable value CGST Rate  ... SGST Rate  \
# 0   2,512.57    2,512.57        0         2,512.57         9  ...         9
# 1        150         150        0              150         9  ...         9
#
# 2 SGST Amount IGST Rate IGST Amount Comp CESS Rate Comp CESS Amount  \
# 0     226.131         0           0              0                0
# 1        13.5         0           0              0                0
#
# 2 State CESS Rate State CESS Amount Total Amount (Rs.)
# 0               0                 0          2,964.833
# 1               0                 0                177
#
# [2 rows x 21 columns]

# %%
df11=pd.read_excel("file_11.xlsx")
df11
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5                                                 NaN
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %%
df11=df11.fillna('')
df11.drop_duplicates()
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
#
#                               Unnamed: 1  None_1            None_2  \
# 0
# 1
# 2                            Description     HSN  Unit of\nmeasure
# 3                            Service Fee  996211               OTH
# 4            Long Distance Pack\ncharges  996211               OTH
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# ...

# %%
header_row_index = 2

# %%
new_header = df11.iloc[header_row_index]       # get the header row
df11 = df11.iloc[header_row_index + 1:]          # keep the data below it
df11.columns = new_header                      # set new header
df11 = df11.reset_index(drop=True)

# %%
df11.columns = df11.columns.str.replace('\n', ' ', regex=True)

# %%
for x in df11.index:
    if df11.loc[x, "Unit of measure"] == '':
        df11.drop(x, inplace=True)

df11
# Out:
# 2 Sr. no.                  Description     HSN Unit of measure Quantity  \
# 0       1                  Service Fee  996211             OTH        1
# 1       2  Long Distance Pack\ncharges  996211             OTH        1
#
# 2 Unit Price Base Amount Discount Assessable value CGST Rate  ... SGST Rate  \
# 0  24,082.01   24,082.01        0        24,082.01         9  ...         9
# 1      1,505       1,505        0            1,505         9  ...         9
#
# 2 SGST Amount IGST Rate IGST Amount Comp CESS Rate Comp CESS Amount  \
# 0   2,167.381         0           0              0                0
# 1      135.45         0           0              0                0
#
# 2 State CESS Rate State CESS Amount Total Amount (Rs.)
# 0               0                 0         28,416.772
# 1               0                 0            1,775.9
#
# [2 rows x 21 columns]

# %%
df12=pd.read_excel("file_12.xlsx")
df12.head()
# Out:
#                                           Unnamed: 0  \
# 0                                        TAX INVOICE
# 1  Invoice From : Swiggy Limited (formerly known ...
# 2                                           Sr.\nno.
# 3                                                  1
# 4                                                  2
#
#                     Unnamed: 1  None_1            None_2    None_3  \
# 0                          NaN     NaN               NaN       NaN
# 1                          NaN     NaN               NaN       NaN
# 2                  Description     HSN  Unit of\nmeasure  Quantity
# 3                  Service Fee  996211               OTH         1
# 4  Long Distance Pack\ncharges  996211               OTH         1
#
#        None_4       None_5    None_6             None_7      None_8  ...  \
# 0         NaN          NaN       NaN                NaN         NaN  ...
# 1         NaN          NaN       NaN                NaN         NaN  ...
# ...

# %%
df12=df12.fillna('')
df12.drop_duplicates()
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
#
#                               Unnamed: 1  None_1            None_2  \
# 0
# 1
# 2                            Description     HSN  Unit of\nmeasure
# 3                            Service Fee  996211               OTH
# 4            Long Distance Pack\ncharges  996211               OTH
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# ...

# %%
header_row_index = 2

# %%
new_header = df12.iloc[header_row_index]       # get the header row
df12 = df12.iloc[header_row_index + 1:]          # keep the data below it
df12.columns = new_header                      # set new header
df12 = df12.reset_index(drop=True)

# %%
df12.columns = df12.columns.str.replace('\n', ' ', regex=True)

# %%
for x in df12.index:
    if df12.loc[x, "Unit of measure"] == '':
        df12.drop(x, inplace=True)

df12
# Out:
# 2 Sr. no.                  Description     HSN Unit of measure Quantity  \
# 0       1                  Service Fee  996211             OTH        1
# 1       2  Long Distance Pack\ncharges  996211             OTH        1
#
# 2 Unit Price Base Amount Discount Assessable value CGST Rate  ... SGST Rate  \
# 0   5,165.81    5,165.81        0         5,165.81         9  ...         9
# 1        315         315        0              315         9  ...         9
#
# 2 SGST Amount IGST Rate IGST Amount Comp CESS Rate Comp CESS Amount  \
# 0     464.923         0           0              0                0
# 1       28.35         0           0              0                0
#
# 2 State CESS Rate State CESS Amount Total Amount (Rs.)
# 0               0                 0          6,095.656
# 1               0                 0              371.7
#
# [2 rows x 21 columns]

# %%
df=pd.read_excel("file_1.xlsx")
df.head(5)
# Out:
#                                           Unnamed: 0  \
# 0                                        TAX INVOICE
# 1  Invoice From : Swiggy Limited (formerly known ...
# 2                                           Sr.\nno.
# 3                                                  1
# 4                                                  2
#
#                     Unnamed: 1  None_1            None_2    None_3  \
# 0                          NaN     NaN               NaN       NaN
# 1                          NaN     NaN               NaN       NaN
# 2                  Description     HSN  Unit of\nmeasure  Quantity
# 3                  Service Fee  996211               OTH         1
# 4  Long Distance Pack\ncharges  996211               OTH         1
#
#        None_4       None_5    None_6             None_7      None_8  ...  \
# 0         NaN          NaN       NaN                NaN         NaN  ...
# 1         NaN          NaN       NaN                NaN         NaN  ...
# ...

# %%
df=df.fillna('')
df.drop_duplicates()
# Out:
#                                            Unnamed: 0  \
# 0                                         TAX INVOICE
# 1   Invoice From : Swiggy Limited (formerly known ...
# 2                                            Sr.\nno.
# 3                                                   1
# 4                                                   2
# 5
# 6                                            SubTotal
# 7          Other Charges - Reimbursement\nof Discount
# 8                                         Grand Total
# 9                                     Amount in Words
# 10  Digitally Signed by\nAuthorised Signature Swig...
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
#
#                               Unnamed: 1  None_1            None_2  \
# 0
# 1
# 2                            Description     HSN  Unit of\nmeasure
# 3                            Service Fee  996211               OTH
# 4            Long Distance Pack\ncharges  996211               OTH
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# ...

# %%
header_row_index = 2

# %%
new_header = df.iloc[header_row_index]       # get the header row
df = df.iloc[header_row_index + 1:]          # keep the data below it
df.columns = new_header                      # set new header
df = df.reset_index(drop=True)

# %%
df.columns = df.columns.str.replace('\n', ' ', regex=True)

# %%
for x in df.index:
    if df.loc[x, "Unit of measure"] == '':
        df.drop(x, inplace=True)

df
# Out:
# 2 Sr. no.                  Description     HSN Unit of measure Quantity  \
# 0       1                  Service Fee  996211             OTH        1
# 1       2  Long Distance Pack\ncharges  996211             OTH        1
#
# 2 Unit Price Base Amount Discount Assessable value CGST Rate  ... SGST Rate  \
# 0   9,386.58    9,386.58        0         9,386.58         9  ...         9
# 1        140         140        0              140         9  ...         9
#
# 2 SGST Amount IGST Rate IGST Amount Comp CESS Rate Comp CESS Amount  \
# 0     844.792         0           0              0                0
# 1        12.6         0           0              0                0
#
# 2 State CESS Rate State CESS Amount Total Amount (Rs.)
# 0               0                 0         11,076.164
# 1               0                 0              165.2
#
# [2 rows x 21 columns]

# %%
Data_Cleaning=pd.concat([df, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12], ignore_index=True)

# %%
Data_Cleaning
# Out:
# 2  Sr. no.                  Description     HSN Unit of measure Quantity  \
# 0        1                  Service Fee  996211             OTH        1
# 1        2  Long Distance Pack\ncharges  996211             OTH        1
# 2        1                  Service Fee  996211             OTH        1
# 3        1                  Service Fee  996211             OTH        1
# 4        2  Long Distance Pack\ncharges  996211             OTH        1
# 5        1                  Service Fee  996211             OTH        1
# 6        2  Long Distance Pack\ncharges  996211             OTH        1
# 7        1                  Service Fee  996211             OTH        1
# 8        2  Long Distance Pack\ncharges  996211             OTH        1
# 9        1                  Service Fee  996211             OTH        1
# 10       2  Long Distance Pack\ncharges  996211             OTH        1
# 11       1                  Service Fee  996211             OTH        1
# ...

# %%
Data_Cleaning['Sr. no.'] = range(1, len(Data_Cleaning) + 1)

# %%
Data_Cleaning
# Out:
# 2   Sr. no.                  Description     HSN Unit of measure Quantity  \
# 0         1                  Service Fee  996211             OTH        1
# 1         2  Long Distance Pack\ncharges  996211             OTH        1
# 2         3                  Service Fee  996211             OTH        1
# 3         4                  Service Fee  996211             OTH        1
# 4         5  Long Distance Pack\ncharges  996211             OTH        1
# 5         6                  Service Fee  996211             OTH        1
# 6         7  Long Distance Pack\ncharges  996211             OTH        1
# 7         8                  Service Fee  996211             OTH        1
# 8         9  Long Distance Pack\ncharges  996211             OTH        1
# 9        10                  Service Fee  996211             OTH        1
# 10       11  Long Distance Pack\ncharges  996211             OTH        1
# 11       12                  Service Fee  996211             OTH        1
# ...

# %% [markdown]
# take the backup

# %%
backup_df = Data_Cleaning.copy()

# %%
Data_Cleaning
# Out:
# 2   Sr. no.                  Description     HSN Unit of measure Quantity  \
# 0         1                  Service Fee  996211             OTH        1
# 1         2  Long Distance Pack\ncharges  996211             OTH        1
# 2         3                  Service Fee  996211             OTH        1
# 3         4                  Service Fee  996211             OTH        1
# 4         5  Long Distance Pack\ncharges  996211             OTH        1
# 5         6                  Service Fee  996211             OTH        1
# 6         7  Long Distance Pack\ncharges  996211             OTH        1
# 7         8                  Service Fee  996211             OTH        1
# 8         9  Long Distance Pack\ncharges  996211             OTH        1
# 9        10                  Service Fee  996211             OTH        1
# 10       11  Long Distance Pack\ncharges  996211             OTH        1
# 11       12                  Service Fee  996211             OTH        1
# ...

# %%
Data_Cleaning.to_excel("Data_Cleaning.xlsx", index=False)

# %%
import IPython
from IPython.display import FileLink

# %%
FileLink("Data_Cleaning.xlsx")
# Out:
# C:\Users\Admin\OneDrive\Desktop\Pandas_data_cleaning\call_list\Data_Cleaning.xlsx

# %%
import zipfile
import os

# Step 1: Save each DataFrame as an Excel file
dataframes = {
    "df1": df,
    "df2": df2,
    "df3": df3,
    "df4": df4,
    "df5": df5,
    "df6": df6,
    "df7": df7,
    "df8": df8,
    "df9": df9,
    "df10": df10,
    "df11": df11,
    "df12": df12,
}

# Save Excel files
for name, dataframe in dataframes.items():
    dataframe.to_excel(f"{name}.xlsx", index=False)

# Step 2: Create a zip file
with zipfile.ZipFile("all_dataframes.zip", "w") as zipf:
    for name in dataframes.keys():
        filename = f"{name}.xlsx"
        zipf.write(filename)

# %%
from IPython.display import FileLink

# %%
FileLink("all_dataframes.zip")
# Out:
# C:\Users\Admin\OneDrive\Desktop\Pandas_data_cleaning\call_list\all_dataframes.zip
